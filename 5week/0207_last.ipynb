# %% [markdown]
# 1. 제약 조건의 종류 5가지 는?
# - NOT NULL : NULL을 설정할 수 없다.
# - UNIQUE : 중복된 값을 가질 수 없다.
# - PRIMARY KEY : NOT NULL + UNIQUE
# - FOREIGN KEY : 다른 테이블의 값을 참조한다 (참조되는 테이블의 값은 반드시 UNIQUE, PRIMARY KEY가 설정되어있어야함.)
# - CHECK : 조건을 사용자가 지정한다.
#
# 2. 아래의 테이블에서 age 컬럼은 20세 이상,  gender 컬럼에 남, 여 만 들어 가도록 제약조건을 주시오.
# ```sql
# create table employees(
#    id int auto_increment primary key, # unique + not null
#     name varchar(50),
#     age int check(age >= 18),
#     gender char(1) CHECK(gender IN('M', 'F'))
# );
# ```
# - 풀이
# ```sql
# create table employees(
#    id int auto_increment primary key, # unique + not null
#     name varchar(50),
#     age int check(age >= 20),         # 20 이상
#     gender char(1) CHECK(gender IN('남', '여')) # '남', '여'만 입력받음
# );
# ```
# 3. 기본키와 외래키에 대하여 설명하시오.
# 기본키: `PRIMARY KEY`
# - null값과 중복값을 허용하지 않는다.
# - 기본키는 유일한 값을 가져야 한다. 포털사이트의 아이디, 전화번호같이
#
# 외래키: `FOREIGN KEY`
# - 다른 테이블의 값을 참조한다.
# - 참조하는 테이블의 값이 변경, 삭제되면 문제가 생길 수 있다.
#
#
# 4. int 의 범위는?
# - 약 -21억부터 21까지. (-214748368 ~ 2147483647)
#
# 5. pymysql 을 활용하여, dept 테이블을 출력하시오.
# ```python
# import pymysql
#
# conn = pymysql.connect(
#     host = 'localhost',
#     user='scott',
#     passwd='tiger',
#     db='scott',
#     charset='utf8'
# )
# curs.conn.cursor()
#
# sql = "select * from dept"
# curs.execute(sql)
# ```
#
#
#
#
# 세줄요약)
# 1. int 는 4바이트, 32 비트, -21억 ~ 21억 이다.
# 2. delete , trucate, drop을 구분하여 쓰자
# 3. 트랜잭션은 일련의 작업 단위이다.
# 4. DB 연결시 connetion 객체 와 cursor 객체를 활용하여, 데이터를 CRUD 할수 있다.
