# %% [markdown]
# 1. 정보은닉이란?
#
# 클래스속 변수명의 노출을 줄이는것.
#
# 2. 아래의 소스코드에서 에러가 나는 이유와 age 50으로 바꾸어 보시오.
# ```python
# class Person:
#     def __init__(self, name, age):
#         self.__name = name
#         self.__age = age
#
#     # if 문의 해당 함수에서 0이 들어 가지 않도록 막음
#     def add_age(self,age):
#         if age < 0:
#             print('나이는 0보다 커야 합니다. 나이 정보 오류')
#         else:
#             self.__age += age
#
#     def __str__(self):
#         return f'이름은 {self.__name}, 나이는 {self.__age}'
#
#
# p = Person('홍길동', 20)
# p.__age = 30
#
# # age를 50 으로 바꿔보시오.
# p.add_age(30)
# print(p) # 이름은 홍길동, 나이는 50
# ```
# - `__변수명` 이렇게 변수명 설정을 하게 되면 정보은닉을 위해 `_클래스명__변수명` 이런식으로 변수명이 저장이된다.
# 오류가 발생하지는 않지만, 원하는 나이값이 출력되지 않는다.
#
#
# 3. 데코레이터란?
# - 기존의 함수를 수정하지 않으면서 추가 기능을 구현할 수 있게 하는것.
#
# 4. 아래와 같이 출력이 나오도독 데코레이션 함수를 만들어 보시오.
# ```python
# def smile():
#     print('^_^')
#
# def confused():
#     print('@_@')
#
# def deco(fun):
#
#     def wrapper():
#         print('emotion!')
#         fun()
#         print('emotion!')
#
#     return wrapper
#
# ================
# # emotion!
# # ^_^
# # emotion!
# ```
# - 풀이
# ```python
# def deco(fun):
#
#     def wrapper():
#         print('emotion!')
#         fun()
#         print('emotion!')
#
#     return wrapper
#
# @deco
# def smile():
#     print('^_^')
#
# smile()
# ```
# 5. 아래와 같이 출력이 나오도록  adder_deco 를 만들어 보시오.
# ```python
# @adder_deco
# def adder1(n1,n2):
#     return n1 + n2
#
# @adder_deco
# def adder2(n1,n2 ,n3):
#     return n1 + n2 + n3
#
# @adder_deco
# def adder3(n1,n2 ,n3,n4):
#     return n1 + n2 + n3 + n4
# '''
# ======
# 8
# 6
# 10
# '''
# adder1(3,5) # 8
# adder2(1,2,3) # 6
# adder3(1,2,3,4) # 6
#
# # 풀이
# def adder_deco(fun):
#     def add(*arg):
#         print('{0}'.format(fun(*arg)))
#     return add
# ```
#
# 6. 아래를 예를 들어 설명하시오.
#  -  클래스 변수 : 클래스속, 메스드밖 에 위치한 함수로, 공유 변수로도 불린다.
#  -  클래스 함수 : 클래스명을 첫번째 인자로 넘기는 함수
#  -  스태틱 함수 : 정적 함수로, 객채와 상관없는 간단한 함수들로 생성한다.
#
# 7. 아래가 에러가 나는 이유를 설명하시오.
# ```python
# class Calculator:
#
#     @staticmethod # 스태틱 메소드 = 정적 메소드 = 간단한 함수들 = 객체와 상관없는 함수들
#     def add(n1, n2):
#         return n1 + n2
#
#     def add2(self, n1,n2): #인스턴스 메소드
#         return n1 + n2
#
#     @staticmethod
#     def mul(n1, n2):
#         return n1 * n2
#
#
# cal = Calculator()
# print(Calculator.add2(10,20))
# ```
# - add2는 인스턴스 메서드이기때문에 객체를 통한 호출만 가능한데, 클래스를 통한 호출을 시도해 오류가 발생한다.
#
# 8. 아래의 출력 결과를 예측하시오.
# ```python
# def decorator1(func):
#     def wrapper():
#         print('decorator1')
#         func()
#     return wrapper
#
# def decorator2(func):
#     def wrapper():
#         print('decorator2')
#         func()
#     return wrapper
#
# #데코레이터를 여러 개 지정
# @decorator1
# @decorator2
# def hello():
#     print('hello')
#
# hello()
# ```
# - decorator1 , decorator2, hello 순서로 출력이 된다.
#
# 9. 아래가 에러가 나는 이유와 수정을 하시오.
# ```python
# class Cirle2:
#     PI = 3.12419
#
#     @classmethod #수정
#     def get_area(cls, radius):
#         return cls.PI * radius * radius
# =============================
# print(Cirle2.PI)
#
# result = Cirle2.get_area(5)
# print(result)
# ```
# - 클래스함수에 데코레이션이 생략되있다.
#
# 10. 프로퍼티 함수에 대하여 설명하시오.(예습)
#
# - 클래스속 변수의 접근시(getter,setter) 좀더 간편하고, 정보은닉을 돕는다.
#
# 3줄 요약:
# 1.정보은닉 이란 변수를 최대한 노출 시키지 않도록 하는것이다.
# 2.파이썬에서 객체의 변수와 값은는 __dict__ 딕셔너리 객체로 따로 관리 한다.
# 3. __변수 이름은 __dict__['_클래스명__변수이름'] 으로 접근 가능하다.
#
# 3줄요약 두번째:
# 4. 데코레이터는 함수호출이며 함수의 파라미터로 콜백함수를 넘긴다.
# 5. 클래스 변수는 공용변수 이며, 각 객체들이 공유 하는 변수이다.
# 6. 프로퍼티는 쪼매 어렵다.

# %%
def decorator(func):
    def wrapper(*args, **kwargs):
        print("Before function execution")
        result = func(*args, **kwargs)
        print("After function execution")
        return result
    return wrapper

@decorator
def say_hello():
    print("Hello, world!")

say_hello()
# Out:
# Before function execution
# Hello, world!
# After function execution
